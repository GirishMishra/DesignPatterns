# %% [markdown]
# <a href="https://colab.research.google.com/github/GirishMishra/DesignPatterns/blob/master/set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
st = {1,2,2,4, 6, 8}

# %%
st
# Out:
# {1, 2, 4, 6, 8}

# %%
netst = {2, 4,8,9, "logical", "film"}

# %%
netst
# Out:
# {2, 4, 8, 9, 'film', 'logical'}

# %%
stl = {(3,6)}

# %%
stl.add(8)

# %%
stl.discard(8)

# %%
stl
# Out:
# {(3, 6)}

# %% [markdown]
# #### Using a list to contain another list:

# %%
list_of_lists = [[3, 6], 1, 2, 'hello']
display(list_of_lists)
print(type(list_of_lists))

# %% [markdown]
# #### Using a tuple to contain a list:

# %%
tuple_with_list = (1, [3, 6], 'world')
display(tuple_with_list)
print(type(tuple_with_list))

# %% [markdown]
# Keep in mind that while you can store a list inside a list or a tuple, you still cannot store a list directly inside a set because of the 'unhashable' nature of lists.

# %%
st4 = {10,20,30,40,50,60}

# %%
st5 = {40,30,60,80, 90, 110}

# %%
st4.intersection(st5)
# Out:
# {30, 40, 60}

# %%
st4
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
st4.intersection_update(st5)

# %%
st4
# Out:
# {30, 40, 60}

# %%
#Map

# %%
map = {"test":1, "test2":2,  3:30}

# %%
map
# Out:
# {'test': 1, 'test2': 2, 3: 30}

# %%
map.values()
# Out:
# dict_values([1, 2, 30])

# %%
map.fromkeys({1,2,3,4})
# Out:
# {1: None, 2: None, 3: None, 4: None}

# %%
map.fromkeys({1,2,3,4},{4,3,4,1})
# Out:
# {1: {1, 3, 4}, 2: {1, 3, 4}, 3: {1, 3, 4}, 4: {1, 3, 4}}

# %%
map.keys()
# Out:
# dict_keys(['test', 'test2', 3])

# %%
map.items()
for (m,v) in map:
    print(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5855/244256299.py in <cell line: 0>()
#       1 map.items()
# ----> 2 for (m,v) in map:
#       3     print(m)
#
# ValueError: too many values to unpack (expected 2)

# %%
dis = {[1,2]:1, "test2":2,  3:30}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5855/2984994246.py in <cell line: 0>()
# ----> 1 dis = {[1,2]:1, "test2":2,  3:30}
#
# TypeError: unhashable type: 'list'

# %%
m = {(1,2):20, (4,5):50}

# %%
m
# Out:
# {(1, 2): 20, (4, 5): 50}

# %%
m.get((1,2))
# Out:
# 20

# %%
map.pop("test")
# Out:
# 1

# %%
map.popitem()
# Out:
# (3, 30)
