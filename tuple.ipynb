# %% [markdown]
# <a href="https://colab.research.google.com/github/GirishMishra/DesignPatterns/blob/master/tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tuple is an imutable data structure

# %%
tuple = 1,2,3,4,5,"Girish", "Urmila"

# %%
tuple.count(1)
# Out:
# 1

# %%
tuple.index("Girish")
#
# Out:
# 5

# %%
t = ("Girish", "Ishika", "Shiv", "Deepika")

# %%
t.count('i')
# Out:
# 0

# %%
t[-1]
# Out:
# 'Deepika'

# %%
t[-4]
# Out:
# 'Girish'

# %%
t[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_890/40288214.py in <cell line: 0>()
# ----> 1 t[-5]
#
# IndexError: tuple index out of range

# %%
t[1:2:1]
# Out:
# ('Ishika',)

# %%
t[:3]
# Out:
# ('Girish', 'Ishika', 'Shiv')

# %%
t[::2]
# Out:
# ('Girish', 'Shiv')

# %%
person = ("Girish", 30, "Ishika", 8,  "Deepika", 28, "Anishka", 2)

# %%
name, age, name1, age1, name2, age2, name3, age3 = person

# %%
name, age, name1, age1, name2, age2, name3, age3
# Out:
# ('Girish', 30, 'Ishika', 8, 'Deepika', 28, 'Anishka', 2)
